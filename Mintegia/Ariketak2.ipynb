# %% [markdown]
# ### 9

# %%
def triangeluarra(n):
    b = 0
    i = 1
    while b < n :
        b = b + i
        i = i + 1
    return b == n

for i in range(1,20):
    if triangeluarra(i):
        print(i)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
def triangeluarra(n):
    b = 0
    i = 1
    while b <= n :
        b = b + i
        i = i + 1
        if b == n :
            return True
    return False

for i in range(1,20):
    if triangeluarra(i):
        print(i)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
def triangeluarra(n):
    b = 0
    i = 1
    while True :
        b = b + i
        i = i + 1
        if b == n :
            return True
        elif b > n :
            return False

for i in range(1,20):
    if triangeluarra(i):
        print(i)
# Out:
# 1
# 3
# 6
# 10
# 15
