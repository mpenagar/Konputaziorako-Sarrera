# %%
izena = input("Kaixo ni mini ChatGPT naiz!!\n\nZein da zure izena? ")
print("Kaixo", izena, "egun ederra gaurkoa.")

adina = int(input("Zenbat urte dituzu? "))
if adina >= 18 :
    print("Ederto!")
    # ....
else :
    print("Barkatu baina adin txikikoekin ezin dut hitzegin...")
# Out:
# Kaixo ni mini ChatGPT naiz!!
#
# Zein da zure izena? Nora
# Kaixo Nora egun ederra gaurkoa.
# Zenbat urte dituzu? 21
# Ederto!
