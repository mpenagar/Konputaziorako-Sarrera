# %%
with open("taula.txt") as f:
    print(f.readlines())
# Out:
# ['*.*.\n', '....\n', '....\n', '****']

# %%
a_* = 34
# Out:
#   File "<ipython-input-11-fb1805afb5c8>", line 1
#     a_* = 34
#         ^
# SyntaxError: invalid syntax
